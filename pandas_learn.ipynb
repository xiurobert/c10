# %%
from pandas import *

# %%
read_csv("spacex_launch_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b5f829eb0723> in <module>
# ----> 1 read_csv("spacex_launch_data.csv")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
read_csv("spacex_launch_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b5f829eb0723> in <module>
# ----> 1 read_csv("spacex_launch_data.csv")
#
# NameError: name 'read_csv' is not defined

# %%
pandas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-609b6d5922fb> in <module>
# ----> 1 pandas
#
# NameError: name 'pandas' is not defined

# %%
from pandas import *

# %%
read_csv("spacex_launch_data.csv")
# Out:
#    Flight Number        Date Time (UTC)  \
# 0              1  2010-06-04   18:45:00
# 1              2  2010-12-08   15:43:00
# 2              3  2012-05-22    7:44:00
# 3              4  2012-10-08    0:35:00
# 4              5  2013-03-01   15:10:00
# 5              6  2013-09-29   16:00:00
# 6              7  2013-12-03   22:41:00
# 7              8  2014-01-06   22:06:00
# 8              9  2014-04-18   19:25:00
# 9             10  2014-07-14   15:15:00
# 10            11  2014-08-05    8:00:00
# 11            12  2014-09-07    5:00:00
# 12            13  2014-09-21    5:52:00
# 13            14  2015-01-10    9:47:00
# 14            15  2015-02-11   23:03:00
# 15            16  2015-03-02    3:50:00
# 16            17  2015-04-14   20:10:00
# 17            18  2015-04-27   23:03:00
# 18            19  2015-06-28   14:21:00
# 19            20  2015-12-22    1:29:00
# 20            21  2016-01-17   18:42:00
# 21            22  2016-03-04   23:35:00
# ...

# %%
newDF=read_csv("spacex_launch_data.csv")[["Date", "Payload Mass (kg)"]].copy()

# %%
import plotly.plotly as py
import plotly as plotly
import plotly.graph_objs as go

plotly.tools.set_credentials_file(username='xiurobert', api_key='2MSIOcSvvlqnyXbW6bHD')

# %%
data = [
    go.Scatter(
        x=newDF["Date"],
        y=newDF["Payload Mass (kg)"]
    )
]

# %%
url = py.plot(data, filename="jiacheng")
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~xiurobert/0 or inside your plot.ly account where it is named 'jiacheng'

# %%
layout = dict(title = 'Graph of Payload Mass/KG against Launch Date',
              xaxis = dict(title = 'Launch Date'),
              yaxis = dict(title = 'Payload Mass (KG)'),
              )

# %%
py.iplot(dict(data=data, layout=layout), filename="jiacheng")
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~xiurobert/0 or inside your plot.ly account where it is named 'jiacheng'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~xiurobert/0.embed" height="525px" width="100%"></iframe>
